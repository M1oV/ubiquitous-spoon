# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dpuIQEd4LVXVSjCOTnnRLee7k6_FTyFd8DWjD4Xwe7MdXKp" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    ops.json	       usercache.json
# banned-players.json  forge.jar.log  patchouli_books    usernamecache.json
# colabconfig.json     journeymap     run.bat	       whitelist.json
# config		     libraries	    run.sh	       world
# defaultconfigs	     logs	    server.properties
# eula.txt	     mods	    user_jvm_args.txt
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 8.tcp.ngrok.io:19811
# Estas jugando a minecraft: forge en su version: 1.18.2
# La versión de Forge es: 1.18.2-40.2.17
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:30:48] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914]
# [03:30:48] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [03:30:49] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2314!/ Service=ModLauncher Env=SERVER
# [03:30:49] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.18.2-40.2.17/fmlcore-1.18.2-40.2.17.jar is missing mods.toml file
# [03:30:49] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.18.2-40.2.17/javafmllanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [03:30:49] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.18.2-40.2.17/lowcodelanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [03:30:49] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.18.2-40.2.17/mclanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [03:30:49] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 1 dependencies adding them to mods collection
# [03:30:52] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [03:30:52] [main/ERROR] [mixin/]: Mixin config epicsamurai.mixins.json does not specify "minVersion" property
# [03:30:52] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [03:30:52] [main/WARN] [mixin/]: Reference map 'arclight.mixins.refmap.json' for epicsamurai.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:30:52] [main/WARN] [mixin/]: Reference map 'nethersdelight.refmap.json' for nethersdelight.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:30:52] [main/WARN] [mixin/]: Reference map 'cristellib-common-refmap.json' for cristellib-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:30:52] [main/WARN] [mixin/]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [03:30:52] [main/INFO] [ne.mi.co.Co.uteamcore/COREMODLOG]: Injected ASMUContainerMenuHook call into ServerPlayer#initMenu
# [03:30:53] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/player/AbstractClientPlayer for invalid dist DEDICATED_SERVER
# [03:30:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/player/AbstractClientPlayer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/player/AbstractClientPlayer for invalid dist DEDICATED_SERVER)
# [03:30:53] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.player.AbstractClientPlayer was not found mixins.irons_spellbooks.json:AbstractClientPlayerMixin
# ############ Journeymap Coremod Potion Effects Renderer: Injected ############
# [03:30:53] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/Gui for invalid dist DEDICATED_SERVER
# [03:30:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/Gui (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/Gui for invalid dist DEDICATED_SERVER)
# [03:30:53] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.Gui was not found mixins.irons_spellbooks.json:GuiMixin
# [03:30:53] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/renderer/entity/ItemRenderer for invalid dist DEDICATED_SERVER
# [03:30:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/entity/ItemRenderer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/renderer/entity/ItemRenderer for invalid dist DEDICATED_SERVER)
# [03:30:53] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.entity.ItemRenderer was not found mixins.irons_spellbooks.json:ItemRendererMixin
# [03:30:53] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/player/LocalPlayer for invalid dist DEDICATED_SERVER
# [03:30:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/player/LocalPlayer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/player/LocalPlayer for invalid dist DEDICATED_SERVER)
# [03:30:53] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.player.LocalPlayer was not found mixins.irons_spellbooks.json:LocalPlayerMixin
# [03:30:53] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/particle/Particle for invalid dist DEDICATED_SERVER
# [03:30:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/particle/Particle (java.lang.RuntimeException: Attempted to load class net/minecraft/client/particle/Particle for invalid dist DEDICATED_SERVER)
# [03:30:53] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.particle.Particle was not found mixins.irons_spellbooks.json:ParticleMixin
# [03:30:53] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/entity/layers/SpinAttackEffectLayer (java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.SpinAttackEffectLayer)
# [03:30:53] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.entity.layers.SpinAttackEffectLayer was not found mixins.irons_spellbooks.json:SpinAttackEffectLayerMixin
# [03:30:59] [main/INFO] [ne.mi.co.Co.uteamcore/COREMODLOG]: Injected ASMUContainerMenuHook call into ServerPlayer#initMenu
# [03:31:02] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `combatroll` for name `distance`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:02] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `combatroll` for name `recharge`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:02] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `combatroll` for name `count`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:02] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `combatroll` for name `longfooted`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:02] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `combatroll` for name `acrobat`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:02] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `combatroll` for name `multi_roll`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: Initializing Easy NPC (Forge) ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Debug Manager ...
# [03:31:03] [modloading-worker-0/WARN] [Easy NPC/]: [Debug Manager] Detected debug log level for Easy NPC with ALL!
# [03:31:03] [modloading-worker-0/WARN] [Easy NPC/]: [Debug Manager] Adjusting log level for Easy NPC from ALL to INFO, for performance reasons!
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: [Debug Manager] Add new logger config for Easy NPC with level INFO ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Constants ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Entity Types ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Blocks ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Blocks Entities ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Items ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC Menu Types ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Register Easy NPC custom data ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: 🗣 Create Easy NPC custom data folder at /workspaces/codespaces-jupyter/Minecraft-server/config/easy_npc ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: Registering Easy NPC common config ...
# [03:31:03] [modloading-worker-0/INFO] [Easy NPC/]: Registering Easy NPC client config ...
# [03:31:04] [modloading-worker-0/INFO] [JarSignVerifier/]: Mod uteamcore is signed with a valid certificate.
# [03:31:04] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [03:31:04] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v40.2.17 Initialized
# [03:31:05] [modloading-worker-0/INFO] [JarSignVerifier/]: Mod usefulbackpacks is signed with a valid certificate.
# [03:31:05] [modloading-worker-0/INFO] [Spartan Shields/]: Constructing Mod: Spartan Shields
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.SpiralSpiresModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.PermafrostModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.NoMoreLavaPocketsModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.NewStoneTypesModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.NetherObsidianSpikesModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.MonsterBoxModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.GlimmeringWealdModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.FairyRingsModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.CorundumModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.ChorusVegetationModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.BlossomTreesModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.BigStoneClustersModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.BigDungeonModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.AzaleaWoodModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.VillagersFollowEmeraldsModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.VexesDieWithTheirMastersModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.UtilityRecipesModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.SnowGolemPlayerHeadsModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.SimpleHarvestModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.SignEditingModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.ReplaceScaffoldingModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.ReacharoundPlacingModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.PoisonPotatoUsageModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.PigLittersModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.PatTheDogsModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.NoteBlockMobSoundsModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.MoreBannerLayersModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.LockRotationModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.HoeHarvestingModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.GrabChickensModule
# [03:31:05] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.GlassShardModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.EnhancedLaddersModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.EmotesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.DragonScalesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.DoubleDoorOpeningModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.CompassesWorkEverywhereModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.CampfiresBoostElytraModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.BetterElytraRocketModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.AutomaticRecipeUnlockModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.ArmedArmorStandsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.TrowelModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.SlimeInABucketModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.SkullPikesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.SeedPouchModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.PickarangModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.PathfinderMapsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.ParrotEggsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.EndermoshMusicDiscModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.ColorRunesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.CameraModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.BundleRecipeModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.BottledCloudModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.BeaconRedirectionModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.AncientTomesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.AmbientDiscsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.AbacusModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.WraithModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.ToretoiseModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.StonelingsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.ShibaModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.FrogsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.FoxhoundModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.ForgottenModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.CrabsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.QuickArmorSwappingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.ItemSharingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.InventorySortingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.HotbarChangerModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.ExpandedItemInteractionsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.EasyTransferingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.ChestsInBoatsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.ZombieVillagersOnNormalModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.SpawnerReplacerModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.OverlayShaderModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.NarratorReadoutModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.GameNerfsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.EnchantmentsBegoneModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.AdjustableChatModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.VariantAnimalTexturesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.UsesForCursesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.UsageTickerModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.SoulCandlesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.MicrocraftingHelperModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.ImprovedTooltipsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.GreenerGrassModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.ChestSearchingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.BackButtonKeybind
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.AutoWalkKeybindModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.WoodenPostsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VerticalSlabsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VerticalPlanksModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantLaddersModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantFurnacesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantChestsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantBookshelvesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ThatchModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.SturdyStoneModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.StoolsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.SoulSandstoneModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ShinglesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ShearVinesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.RopeModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.OrientalPaletteModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.NetherBrickFenceGateModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MoreStoneVariantsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MorePottedPlantsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MoreBrickTypesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MidoriModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.LeafCarpetModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.IndustrialPaletteModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.HedgesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GrateModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GoldBarsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GlassItemFrameModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.FramedGlassModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.DuskboundBlocksModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.CompressedBlocksModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.CelebratoryLampsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.RedstoneRandomizerModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.PistonsMoveTileEntitiesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.ObsidianPlateModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.MetalButtonsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.JukeboxAutomationModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.IronRodModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.GravisandModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.FeedingTroughModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.EnderWatcherModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.DispensersPlaceBlocksModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.ChuteModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.ChainsConnectBlocksModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.TotemOfHoldingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.TinyPotatoModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.PipesModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.MatrixEnchantingModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.MagnetsModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.CrateModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.BackpackModule
# [03:31:06] [modloading-worker-0/INFO] [quark/]: Dispatching Module Step CONSTRUCT
# [03:31:06] [modloading-worker-0/INFO] [Spartan Weaponry/]: Constructing Mod: Spartan Weaponry
# [03:31:06] [modloading-worker-0/INFO] [Spartan Weaponry/]: Initialising API! Version: 9
# [03:31:06] [modloading-worker-0/INFO] [Spartan Weaponry/]: Spartan Weaponry API version 9 has been initalized!
# [03:31:06] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [03:31:06] [modloading-worker-0/INFO] [be.fl.ex.ExpandAbility/]: ExpandAbility here, who dis?
# [03:31:07] [modloading-worker-0/INFO] [Cristel Lib/]: dumping Runtime Pack's assets and data
# [03:31:10] [main/INFO] [quark/]: Dispatching Module Step REGISTER
# [03:31:12] [main/INFO] [quark/]: Dispatching Module Step POST_REGISTER
# [03:31:15] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `shulker_shell`, expected `supplementaries`. This could be a intended override, but in most cases indicates a broken mod.
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttackData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttackData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.AttributeData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ModelData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.NavigationData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.OwnerData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ProfessionData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ScaleData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ScaleData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.ScaleData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.SkinData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.SkinData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.SkinData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.SkinData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCBaseEntity from interface de.markusbordihn.easynpc.entity.easynpc.data.VariantData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityObjectiveData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityObjectiveData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityObjectiveData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityTradingData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityTradingData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityTradingData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityTradingData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityTradingData
# [03:31:16] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class de.markusbordihn.easynpc.entity.EasyNPCEntityData from interface de.markusbordihn.easynpc.entity.data.EntityTradingData
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityLeafcutterAnt from class com.github.alexthe666.alexsmobs.entity.EntityDevilsHolePupfish
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityMantisShrimp from class com.github.alexthe666.alexsmobs.entity.EntitySkelewag
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [03:31:19] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# ...
# [04:24:08] [Server thread/INFO] [minecraft/DedicatedServer]: Djprax was shot by Fenire the Fiery
# [04:24:08] [Server thread/INFO] [tombstone/]: The player Djprax has successfully been saved
# [04:24:11] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2389ms or 47 ticks behind
# [04:24:19] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was blown up by Zombie
# [04:24:19] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:24:34] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 8121ms or 162 ticks behind
# [04:24:41] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Spawners Destroyed: 16
# [04:24:52] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was shot by Skeleton
# [04:24:52] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:25:16] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was blown up by Spider
# [04:25:16] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:25:17] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:25:40] [Server thread/INFO] [minecraft/DedicatedServer]: Djprax was burnt to a crisp whilst fighting Fenire the Fiery
# [04:25:40] [Server thread/INFO] [tombstone/]: The player Djprax has successfully been saved
# > [04:25:48] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Spawners Destroyed: 17
# [04:25:54] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: MTNK25 moved too quickly! -1.8506328316079816,0.0,-9.891982665006026
# [04:25:54] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 5331ms or 106 ticks behind
# [04:26:11] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2404ms or 48 ticks behind
# [04:26:31] [Server thread/INFO] [minecraft/LivingEntity]: Named entity WitherSkeleton['Fenire the Fiery'/34780, l='ServerLevel[world]', x=274.29, y=67.00, z=214.65] died: Fenire the Fiery was slain by Djprax
# [04:26:46] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Spawners Destroyed: 18
# [04:26:51] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Spawners Destroyed: 19
# [04:26:57] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Spawners Destroyed: 20
# [04:27:09] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 blew up
# [04:27:09] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:27:21] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Spawners Destroyed: 21
# [04:27:34] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:28:22] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was doomed to fall by Bahryn'muul, Entombed Watcher
# [04:28:22] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:28:34] [Server thread/INFO] [minecraft/DedicatedServer]: Djprax was slain by Veril the Withered
# [04:28:34] [Server thread/INFO] [tombstone/]: The player Djprax has successfully been saved
# [04:28:35] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> ise un pabajo
# [04:28:40] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was slain by Bahryn'muul, Entombed Watcher
# [04:28:40] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:28:42] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:28:52] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2034ms or 40 ticks behind
# [04:29:12] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was blown up by Bahryn'muul, Entombed Watcher
# [04:29:12] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Server handling Packets.C2S_AttackRequest - No current attack hand!
# [04:29:12] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Combo count: 6 is dual wielding: false
# [04:29:12] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Main-hand stack: 0 air
# [04:29:12] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Off-hand stack: 0 air
# [04:29:12] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Selected slot server: 0 | client: 0
# [04:29:12] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:29:14] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:29:21] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was slain by Bahryn'muul, Entombed Watcher
# [04:29:21] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:29:43] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was doomed to fall
# [04:29:44] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:29:45] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:30:23] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Ignoring UseItemOnPacket from Djprax: hit position BlockPos{x=53, y=85, z=-51} too far away from player BlockPos{x=252, y=68, z=227}.
# [04:30:28] [Server thread/INFO] [minecraft/DedicatedServer]: Djprax was slain by Veril the Withered
# [04:30:28] [Server thread/INFO] [tombstone/]: The player Djprax has successfully been saved
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:30:47] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 was doomed to fall
# [04:30:47] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:31:04] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: MTNK25 moved too quickly! 1.7475865912682593,-1.059922469862471,10.029378361872887
# [04:31:53] [Server thread/INFO] [minecraft/DedicatedServer]: MTNK25 fell from a high place
# [04:31:53] [Server thread/INFO] [tombstone/]: The player MTNK25 has successfully been saved
# [04:31:54] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:32:37] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:33:06] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> leo
# [04:33:13] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> encontre a alguien q creo q t intertesara
# [04:33:17] [Server thread/INFO] [minecraft/DedicatedServer]: <MTNK25> oe villar, como va el horno del son of sins?
# [04:33:22] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> ?
# [04:33:24] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> tai esta
# [04:33:27] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> q tiene
# [04:33:33] [Server thread/INFO] [minecraft/Villager]: Villager VillagerEntityMCA['Mevlide'/15700, l='ServerLevel[world]', x=202.86, y=82.00, z=-1249.44] died, message: 'Mevlide was poked to death by a sweet berry bush'
# [04:33:33] [Server thread/INFO] [minecraft/LivingEntity]: Named entity VillagerEntityMCA['Mevlide'/15700, l='ServerLevel[world]', x=202.86, y=82.00, z=-1249.44] died: Mevlide was poked to death by a sweet berry bush
# [04:33:39] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2005ms or 40 ticks behind
# [04:33:43] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Creative Mode]
# [04:33:57] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2434ms or 48 ticks behind
# [04:34:07] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> matala
# [04:34:13] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:34:22] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Survival Mode]
# [04:34:26] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> ya
# [04:34:45] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Creative Mode]
# [04:34:50] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Survival Mode]
# [04:36:37] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Creative Mode]
# [04:36:42] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> ya
# [04:36:43] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Survival Mode]
# [04:36:43] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> leo
# [04:36:44] [Server thread/INFO] [minecraft/DedicatedServer]: <CommanderPBJ> mira
# [04:37:41] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:39:15] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Creative Mode]
# [04:39:26] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Survival Mode]
# [04:40:46] [Server thread/INFO] [minecraft/LivingEntity]: Named entity WitherSkeleton['Veril the Withered'/42869, l='ServerLevel[world]', x=251.02, y=67.00, z=221.57] died: Veril the Withered was slain by Djprax
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:41:35] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Creative Mode]
# [04:41:39] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Survival Mode]
# [04:42:41] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:46:21] [Server thread/INFO] [minecraft/DedicatedServer]: Leo fell from a high place
# [04:46:21] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [04:46:56] [Server thread/INFO] [minecraft/DedicatedServer]: [MTNK25: Set own game mode to Creative Mode]
# [04:47:41] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:49:48] [Server thread/INFO] [minecraft/DedicatedServer]: Djprax withered away whilst fighting Wither Skeleton
# [04:49:48] [Server thread/INFO] [tombstone/]: The player Djprax has successfully been saved
# [04:50:00] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2029ms or 40 ticks behind
# [04:50:03] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: CommanderPBJ lost connection: Timed out
# [04:50:03] [Server thread/INFO] [minecraft/DedicatedServer]: CommanderPBJ left the game
# [04:50:03] [Server thread/WARN] [minecraft/Connection]: handleDisconnection() called twice
# [04:50:43] [Server thread/INFO] [minecraft/DedicatedServer]: Leo fell from a high place
# [04:50:43] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:52:10] [Server thread/INFO] [minecraft/Villager]: Villager VillagerEntityMCA['Lidija'/54511, l='ServerLevel[world]', x=55.39, y=75.00, z=-1150.29] died, message: 'Lidija was slain by Zombie'
# [04:52:10] [Server thread/INFO] [minecraft/LivingEntity]: Named entity VillagerEntityMCA['Lidija'/54511, l='ServerLevel[world]', x=55.39, y=75.00, z=-1150.29] died: Lidija was slain by Zombie
# > [04:52:43] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:53:07] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: Djprax lost connection: Disconnected
# [04:53:07] [Server thread/INFO] [minecraft/DedicatedServer]: Djprax left the game
# [04:55:46] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was slain by Silvana Heartfire
# [04:55:46] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [04:56:23] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was slain by Silvana Heartfire
# [04:56:23] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [04:57:40] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was struck by lightning whilst fighting Silvana Heartfire
# [04:57:40] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [04:57:43] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [04:58:30] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was struck by lightning whilst fighting Silvana Heartfire
# [04:58:30] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [04:58:58] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was killed by Silvana Heartfire using magic
# [04:58:58] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [05:00:06] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was struck by lightning whilst fighting Silvana Heartfire
# [05:00:06] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [05:00:37] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was slain by Silvana Heartfire
# [05:00:37] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [05:00:37] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Server handling Packets.C2S_AttackRequest - No current attack hand!
# [05:00:37] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Combo count: 16 is dual wielding: false
# [05:00:37] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Main-hand stack: 0 air
# [05:00:37] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Off-hand stack: 0 air
# [05:00:37] [Server thread/ERROR] [ne.be.ne.ServerNetwork/]: Selected slot server: 0 | client: 0
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [05:01:07] [Server thread/INFO] [minecraft/DedicatedServer]: Leo was slain by Silvana Heartfire
# [05:01:07] [Server thread/INFO] [tombstone/]: The player Leo has successfully been saved
# [05:01:24] [Server thread/INFO] [minecraft/LivingEntity]: Named entity Witch['Silvana Heartfire'/61487, l='ServerLevel[world]', x=165.16, y=-26.00, z=-1158.64] died: Silvana Heartfire was slain by Leo
# [05:02:43] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# [05:07:43] [Server thread/INFO] [co.Br.ba.BrassAmberBattleTowers/]: Setting obelisk data
# >
